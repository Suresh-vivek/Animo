# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.impute import SimpleImputer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import hstack
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("anime_with_synopsis.csv");
df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1              Action, Drama, Mystery, Sci-Fi, Space
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4          Adventure, Fantasy, Shounen, Supernatural
#
#                                             Synopsis
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  ches are individuals with special powers like ...
# 4  It is the dark century and the people are suff...

# %%
df.shape
# Out:
# (16214, 5)

# %%
df.isnull().sum()
# Out:
# MAL_ID      0
# Name        0
# Score       0
# Genres      0
# Synopsis    8
# dtype: int64

# %%
missing_synopsis = df[df['Synopsis'].isnull()]
print("Rows with missing synopsis:")
print(missing_synopsis)
# Out:
# Rows with missing synopsis:
#        MAL_ID                                               Name    Score  \
# 11451   34755  Kuma no Gakkou: Patissier Jackie to Ohisama no...  Unknown
# 11469   34794                                Yukai na Animal Bus  Unknown
# 13686   38475                                   Yuru Camp△ Movie  Unknown
# 15025   40714  Youkai Watch Jam: Youkai Gakuen Y - N to no So...     6.28
# 15747   42717                   Kaeru no Pickles: Kimochi no Iro  Unknown
# 16056   44848                                        Iii Icecrin  Unknown
# 16110   45731                   Argonavis from BanG Dream! Movie  Unknown
# 16120   46095                          Vivy: Fluorite Eye's Song  Unknown
#
#                                            Genres Synopsis
# 11451                                Comedy, Kids      NaN
# 11469                                Comedy, Kids      NaN
# 13686                       Comedy, Slice of Life      NaN
# 15025  Comedy, Demons, Kids, Supernatural, School      NaN
# 15747                         Slice of Life, Kids      NaN
# 16056                                        Kids      NaN
# 16110                                       Music      NaN
# 16120                                      Sci-Fi      NaN

# %%
df['Synopsis'].fillna('No synopsis available', inplace=True)
missing_synopsis = df[df['Synopsis'].isnull()]
print("Rows with missing synopsis:")
print(missing_synopsis)
# Out:
# Rows with missing synopsis:
# Empty DataFrame
# Columns: [MAL_ID, Name, Score, Genres, Synopsis]
# Index: []

# %%
unknown_scores= df[df['Score']== "Unknown"]
print(unknown_scores)
# Out:
#        MAL_ID                                               Name    Score  \
# 1347     1547                                   Obake no Q-tarou  Unknown
# 1439     1656                                    PostPet Momobin  Unknown
# 1512     1739                         Shibawanko no Wa no Kokoro  Unknown
# 1619     1863                            Silk Road Shounen Yuuto  Unknown
# 1808     2073  Hengen Taima Yakou Karura Mau! Sendai Kokeshi ...  Unknown
# ...       ...                                                ...      ...
# 16209   48481                    Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                                       Mieruko-chan  Unknown
# 16211   48488                    Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491                        Yama no Susume: Next Summit  Unknown
# 16213   48492                                      Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 1347         Comedy, School, Slice of Life, Supernatural
# 1439                                        Comedy, Kids
# 1512                                                Kids
# 1619                      Adventure, Fantasy, Historical
# 1808                                      Horror, Shoujo
# ...                                                  ...
# 16209                   Adventure, Mystery, Supernatural
# 16210                       Comedy, Horror, Supernatural
# 16211  Mystery, Dementia, Horror, Psychological, Supe...
# 16212                   Adventure, Slice of Life, Comedy
# 16213                                    Action, Fantasy
#
#                                                 Synopsis
# 1347   Q-taro, a monster, is living with the Ohara fa...
# 1439   omo and Komomo can deliver mail from anyone, t...
# 1512   Based on a japanese children`s book by Yoshie ...
# 1619   hen a boy Yuto visits Qinghai in China, he is ...
# 1808   Shoko and Maiko Ougi are apparently two ordina...
# ...                                                  ...
# 16209  No synopsis information has been added to this...
# 16210  ko is a typical high school student whose life...
# 16211          Sequel to Higurashi no Naku Koro ni Gou .
# 16212                          New Yama no Susume anime.
# 16213  Solar calendar year 2020: grotesque organisms ...
#
# [5123 rows x 5 columns]

# %%
df['Score'].fillna('Unknown', inplace=True)
df['Score'] = pd.to_numeric(df['Score'], errors='coerce')
imputer = SimpleImputer(strategy='median')
df['Score'] = imputer.fit_transform(df[['Score']])
row_1347 = df.iloc[1347]  
print(row_1347)
# Out:
# MAL_ID                                                   1547
# Name                                         Obake no Q-tarou
# Score                                                    6.57
# Genres            Comedy, School, Slice of Life, Supernatural
# Synopsis    Q-taro, a monster, is living with the Ohara fa...
# Name: 1347, dtype: object

# %%
# Step 1: Split genres string into individual genres
genres_split = df['Genres'].str.split(', ')

# Step 2: Flatten the list of genres
all_genres = [genre for genres_list in genres_split.dropna() for genre in genres_list]

# Step 3: Use value_counts to count occurrences of each genre
genre_counts = pd.Series(all_genres).value_counts()

# Display the count of different genres
print("Count of Different Genres:")
print(genre_counts)
# Out:
# Count of Different Genres:
# Comedy           5975
# Action           3846
# Fantasy          3202
# Adventure        2942
# Kids             2665
# Drama            2589
# Sci-Fi           2551
# Music            2241
# Shounen          2003
# Slice of Life    1912
# Romance          1852
# School           1577
# Supernatural     1410
# Historical       1129
# Mecha            1094
# Magic            1056
# Seinen            830
# Ecchi             767
# Mystery           721
# Sports            708
# Shoujo            688
# Parody            649
# Super Power       627
# Military          572
# Dementia          510
# Space             491
# Demons            434
# Horror            430
# Martial Arts      416
# Game              386
# Harem             357
# Psychological     340
# Police            243
# Samurai           202
# Cars              133
# Vampire           133
# Thriller          130
# Shounen Ai        100
# Josei              96
# Shoujo Ai          79
# Unknown            63
# Yaoi               31
# dtype: int64

# %%
scaler = MinMaxScaler()
numeric_scores_normalized = scaler.fit_transform(df['Score'].values.reshape(-1, 1))

synopsis_vectorizer = TfidfVectorizer(stop_words='english')
synopsis_matrix = synopsis_vectorizer.fit_transform(df['Synopsis'].fillna(''))

# Create a TF-IDF vectorizer for genres
genres_vectorizer = TfidfVectorizer(stop_words='english')
genres_matrix = genres_vectorizer.fit_transform(df['Genres'])

# Combine the TF-IDF matrices for synopses and genres
combined_matrix = hstack([synopsis_matrix, genres_matrix,numeric_scores_normalized])


# Calculate cosine similarity for combined features
combined_similarity = cosine_similarity(combined_matrix)

# Display the cosine similarity matrix for combined features
combined_similarity_df = pd.DataFrame(combined_similarity, index=df['Name'], columns=df['Name'])
print("Cosine Similarity Matrix for Combined Features (Synopsis and Genres):")
print(combined_similarity_df.tail(10))
# Out:
# Cosine Similarity Matrix for Combined Features (Synopsis and Genres):
# Name                             Cowboy Bebop  \
# Name
# SK∞: Crazy Rock Jam                  0.269809
# Kyoukai Senki                        0.295811
# D_Cide Traumerei                     0.394066
# Tsuki to Laika to Nosferatu          0.442421
# Wan Jie Shen Zhu 3rd Season          0.323482
# Daomu Biji Zhi Qinling Shen Shu      0.288584
# Mieruko-chan                         0.266046
# Higurashi no Naku Koro ni Sotsu      0.229828
# Yama no Susume: Next Summit          0.331497
# Scarlet Nexus                        0.327231
#
# Name                             Cowboy Bebop: Tengoku no Tobira    Trigun  \
# Name
# SK∞: Crazy Rock Jam                                     0.218705  0.262498
# Kyoukai Senki                                           0.288261  0.293865
# D_Cide Traumerei                                        0.323235  0.400493
# Tsuki to Laika to Nosferatu                             0.425016  0.322498
# Wan Jie Shen Zhu 3rd Season                             0.220647  0.328427
# Daomu Biji Zhi Qinling Shen Shu                         0.352747  0.289029
# Mieruko-chan                                            0.226087  0.257135
# Higurashi no Naku Koro ni Sotsu                         0.290908  0.216989
# Yama no Susume: Next Summit                             0.220647  0.327543
# Scarlet Nexus                                           0.303590  0.307321
#
# Name                             Witch Hunter Robin  Bouken Ou Beet  \
# Name
# SK∞: Crazy Rock Jam                        0.189897        0.181776
# Kyoukai Senki                              0.261976        0.188566
# D_Cide Traumerei                           0.383821        0.334944
# Tsuki to Laika to Nosferatu                0.191941        0.184649
# Wan Jie Shen Zhu 3rd Season                0.191583        0.442189
# Daomu Biji Zhi Qinling Shen Shu            0.402743        0.402592
# Mieruko-chan                               0.283057        0.321992
# Higurashi no Naku Koro ni Sotsu            0.303894        0.255428
# Yama no Susume: Next Summit                0.191583        0.273744
# Scarlet Nexus                              0.267333        0.321241
#
# Name                             Eyeshield 21  Hachimitsu to Clover  \
# Name
# SK∞: Crazy Rock Jam                  0.507429              0.248901
# Kyoukai Senki                        0.302395              0.215709
# D_Cide Traumerei                     0.278213              0.268219
# Tsuki to Laika to Nosferatu          0.209713              0.212504
# Wan Jie Shen Zhu 3rd Season          0.214865              0.212504
# Daomu Biji Zhi Qinling Shen Shu      0.214865              0.212504
# Mieruko-chan                         0.261458              0.243238
# Higurashi no Naku Koro ni Sotsu      0.209713              0.212504
# Yama no Susume: Next Summit          0.256450              0.399147
# Scarlet Nexus                        0.323729              0.212504
#
# Name                             Hungry Heart: Wild Striker  \
# Name
# SK∞: Crazy Rock Jam                                0.457474
# Kyoukai Senki                                      0.205644
# D_Cide Traumerei                                   0.217809
# Tsuki to Laika to Nosferatu                        0.208492
# Wan Jie Shen Zhu 3rd Season                        0.200303
# Daomu Biji Zhi Qinling Shen Shu                    0.200303
# Mieruko-chan                                       0.241176
# Higurashi no Naku Koro ni Sotsu                    0.200303
# Yama no Susume: Next Summit                        0.446341
# Scarlet Nexus                                      0.209372
#
# Name                             Initial D Fourth Stage   Monster  ...  \
# Name                                                               ...
# SK∞: Crazy Rock Jam                            0.374485  0.227350  ...
# Kyoukai Senki                                  0.273049  0.232250  ...
# D_Cide Traumerei                               0.309811  0.271834  ...
# Tsuki to Laika to Nosferatu                    0.232416  0.235085  ...
# Wan Jie Shen Zhu 3rd Season                    0.221461  0.229369  ...
# Daomu Biji Zhi Qinling Shen Shu                0.221461  0.317441  ...
# Mieruko-chan                                   0.218386  0.350937  ...
# Higurashi no Naku Koro ni Sotsu                0.214759  0.494852  ...
# Yama no Susume: Next Summit                    0.214759  0.229369  ...
# Scarlet Nexus                                  0.291459  0.234598  ...
#
# Name                             SK∞: Crazy Rock Jam  Kyoukai Senki  \
# Name
# SK∞: Crazy Rock Jam                         1.000000       0.169825
# Kyoukai Senki                               0.169825       1.000000
# D_Cide Traumerei                            0.169825       0.268738
# Tsuki to Laika to Nosferatu                 0.169825       0.181649
# Wan Jie Shen Zhu 3rd Season                 0.169825       0.171333
# Daomu Biji Zhi Qinling Shen Shu             0.169825       0.171333
# Mieruko-chan                                0.229012       0.171333
# Higurashi no Naku Koro ni Sotsu             0.169825       0.171333
# Yama no Susume: Next Summit                 0.234703       0.171333
# Scarlet Nexus                               0.169825       0.332357
#
# Name                             D_Cide Traumerei  \
# Name
# SK∞: Crazy Rock Jam                      0.169825
# Kyoukai Senki                            0.268738
# D_Cide Traumerei                         1.000000
# Tsuki to Laika to Nosferatu              0.180788
# Wan Jie Shen Zhu 3rd Season              0.411970
# Daomu Biji Zhi Qinling Shen Shu          0.249216
# Mieruko-chan                             0.176072
# Higurashi no Naku Koro ni Sotsu          0.171333
# Yama no Susume: Next Summit              0.255346
# Scarlet Nexus                            0.400868
#
# Name                             Tsuki to Laika to Nosferatu  \
# Name
# SK∞: Crazy Rock Jam                                 0.169825
# Kyoukai Senki                                       0.181649
# D_Cide Traumerei                                    0.180788
# Tsuki to Laika to Nosferatu                         1.000000
# Wan Jie Shen Zhu 3rd Season                         0.171333
# Daomu Biji Zhi Qinling Shen Shu                     0.171333
# Mieruko-chan                                        0.172710
# Higurashi no Naku Koro ni Sotsu                     0.171333
# Yama no Susume: Next Summit                         0.171333
# Scarlet Nexus                                       0.171859
#
# Name                             Wan Jie Shen Zhu 3rd Season  \
# Name
# SK∞: Crazy Rock Jam                                 0.169825
# Kyoukai Senki                                       0.171333
# D_Cide Traumerei                                    0.411970
# Tsuki to Laika to Nosferatu                         0.171333
# Wan Jie Shen Zhu 3rd Season                         1.000000
# Daomu Biji Zhi Qinling Shen Shu                     0.719766
# Mieruko-chan                                        0.171333
# Higurashi no Naku Koro ni Sotsu                     0.171333
# Yama no Susume: Next Summit                         0.315989
# Scarlet Nexus                                       0.382424
#
# Name                             Daomu Biji Zhi Qinling Shen Shu  \
# Name
# SK∞: Crazy Rock Jam                                     0.169825
# Kyoukai Senki                                           0.171333
# D_Cide Traumerei                                        0.249216
# Tsuki to Laika to Nosferatu                             0.171333
# Wan Jie Shen Zhu 3rd Season                             0.719766
# Daomu Biji Zhi Qinling Shen Shu                         1.000000
# Mieruko-chan                                            0.305207
# Higurashi no Naku Koro ni Sotsu                         0.346961
# Yama no Susume: Next Summit                             0.262086
# Scarlet Nexus                                           0.171333
#
# Name                             Mieruko-chan  \
# Name
# SK∞: Crazy Rock Jam                  0.229012
# Kyoukai Senki                        0.171333
# D_Cide Traumerei                     0.176072
# Tsuki to Laika to Nosferatu          0.172710
# Wan Jie Shen Zhu 3rd Season          0.171333
# Daomu Biji Zhi Qinling Shen Shu      0.305207
# Mieruko-chan                         1.000000
# Higurashi no Naku Koro ni Sotsu      0.371269
# Yama no Susume: Next Summit          0.220013
# Scarlet Nexus                        0.171333
#
# Name                             Higurashi no Naku Koro ni Sotsu  \
# Name
# SK∞: Crazy Rock Jam                                     0.169825
# Kyoukai Senki                                           0.171333
# D_Cide Traumerei                                        0.171333
# Tsuki to Laika to Nosferatu                             0.171333
# Wan Jie Shen Zhu 3rd Season                             0.171333
# Daomu Biji Zhi Qinling Shen Shu                         0.346961
# Mieruko-chan                                            0.371269
# Higurashi no Naku Koro ni Sotsu                         1.000000
# Yama no Susume: Next Summit                             0.171333
# Scarlet Nexus                                           0.171333
#
# Name                             Yama no Susume: Next Summit  Scarlet Nexus
# Name
# SK∞: Crazy Rock Jam                                 0.234703       0.169825
# Kyoukai Senki                                       0.171333       0.332357
# D_Cide Traumerei                                    0.255346       0.400868
# Tsuki to Laika to Nosferatu                         0.171333       0.171859
# Wan Jie Shen Zhu 3rd Season                         0.315989       0.382424
# Daomu Biji Zhi Qinling Shen Shu                     0.262086       0.171333
# Mieruko-chan                                        0.220013       0.171333
# Higurashi no Naku Koro ni Sotsu                     0.171333       0.171333
# Yama no Susume: Next Summit                         1.000000       0.178191
# Scarlet Nexus                                       0.178191       1.000000
#
# [10 rows x 16214 columns]

# %%
def recommend_anime(anime_name, similarity_matrix, df, num_recommendations=5):
    idx = df[df['Name'] == anime_name].index[0]
    sim_scores = list(enumerate(similarity_matrix[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:num_recommendations + 1]
    recommendations = [df['Name'][i[0]] for i in sim_scores]
    return recommendations

# Example usage
anime_name = 'One Punch Man'
recommendations = recommend_anime(anime_name, combined_similarity_df.values, df, num_recommendations=20)
print(f"Recommendations for {anime_name}: {recommendations}")
# Out:
# Recommendations for One Punch Man: ['One Punch Man: Road to Hero', 'One Punch Man 2nd Season', 'One Punch Man Specials', 'One Punch Man 2nd Season Specials', 'One Punch Man 2nd Season Commemorative Special', 'Towa no Quon 6: Towa no Quon', 'Towa no Quon 4: Guren no Shoushin', 'Towa no Quon 5: Souzetsu no Raifuku', 'Towa no Quon 1: Utakata no Kaben', 'Toaru Kagaku no Railgun S', 'Toaru Kagaku no Railgun T', 'Samurai Flamenco', 'Toaru Kagaku no Railgun', 'Tokyo ESP', 'K: Missing Kings', 'Toaru Kagaku no Railgun: Misaka-san wa Ima Chuumoku no Mato Desu kara', 'Towa no Quon 2: Konton no Ranbu', 'Kiddy GiRL-AND', 'Canaan', 'Witchblade']
